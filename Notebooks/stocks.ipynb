# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import geopandas as gpd
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import re
import os

# %% [markdown]
# ### ·          SUB – Submission data set; this includes one record for each XBRL submission. The set includes fields of information pertinent to the submission and the filing entity. Information is extracted from the SEC’s EDGAR system and the filings submitted to the SEC by registrants.
#
# ### ·          NUM – Number data set; this includes one row for each distinct amount from each submission included in the SUB data set. The Number data set includes, for every submission, for each primary financial statement as it is rendered by the SEC Viewer/Previewer, all line item values.
#
# ### ·         TAG – Tag data set; includes defining information about each tag.  Information includes tag descriptions (documentation labels), taxonomy version information and other tag attributes.
#
# ### ·          PRE – Presentation data set; this provides information about how the tags and numbers were presented in the primary financial statements.

# %% [markdown]
# # 2020 Quarters

# %%
df = pd.read_csv('../Data/num_2020q3.txt', sep='/t', engine='python', header=None, names=['adsh','tag','version','ddate','qtrs', 'uom','coreg','value', 'footnote'])
df
# Out:
#                                                       adsh   tag  version  \
# 0        adsh\ttag\tversion\tcoreg\tddate\tqtrs\tuom\tv...  None      NaN
# 1        0001661920-20-000055\tEntityCommonStockSharesO...  None      NaN
# 2        0001469709-20-000039\tEntityCommonStockSharesO...  None      NaN
# 3        0001437557-20-000069\tEntityCommonStockSharesO...  None      NaN
# 4        0001628280-20-010192\tEntityCommonStockSharesO...  None      NaN
# ...                                                    ...   ...      ...
# 2351636  0001731122-20-000975\tSharesIssuedInKindForPre...  None      NaN
# 2351637  0001731122-20-000975\tStockIssuedPursuantToWar...  None      NaN
# 2351638  0001731122-20-000975\tStockIssuedPursuantToWar...  None      NaN
# 2351639  0001731122-20-000975\tStockoptionsComp\t000173...  None      NaN
# 2351640  0001731122-20-000975\tStockoptionsComp\t000173...  None      NaN
#
#          ddate  qtrs  uom  coreg  value  footnote
# 0          NaN   NaN  NaN    NaN    NaN       NaN
# 1          NaN   NaN  NaN    NaN    NaN       NaN
# 2          NaN   NaN  NaN    NaN    NaN       NaN
# 3          NaN   NaN  NaN    NaN    NaN       NaN
# 4          NaN   NaN  NaN    NaN    NaN       NaN
# ...        ...   ...  ...    ...    ...       ...
# 2351636    NaN   NaN  NaN    NaN    NaN       NaN
# 2351637    NaN   NaN  NaN    NaN    NaN       NaN
# 2351638    NaN   NaN  NaN    NaN    NaN       NaN
# 2351639    NaN   NaN  NaN    NaN    NaN       NaN
# 2351640    NaN   NaN  NaN    NaN    NaN       NaN
#
# [2351641 rows x 9 columns]

# %%
df = pd.read_csv('../Data/num_2020q3.txt', sep=r'\s{2,}', engine='python', header=None, names=['adsh','tag','version','ddate','qtrs', 'uom','coreg','value', 'footnote'])
df
# Out:
#                                                       adsh  \
# 0        adsh\ttag\tversion\tcoreg\tddate\tqtrs\tuom\tv...
# 1        0001661920-20-000055\tEntityCommonStockSharesO...
# 2        0001469709-20-000039\tEntityCommonStockSharesO...
# 3        0001437557-20-000069\tEntityCommonStockSharesO...
# 4        0001628280-20-010192\tEntityCommonStockSharesO...
# ...                                                    ...
# 2351636  0001731122-20-000975\tSharesIssuedInKindForPre...
# 2351637  0001731122-20-000975\tStockIssuedPursuantToWar...
# 2351638  0001731122-20-000975\tStockIssuedPursuantToWar...
# 2351639  0001731122-20-000975\tStockoptionsComp\t000173...
# 2351640  0001731122-20-000975\tStockoptionsComp\t000173...
#
#                                           tag version ddate  qtrs   uom  \
# 0                                        None    None  None  None  None
# 1          20200630\t0\tshares\t24944891.0000    None  None  None  None
# 2        20200630\t0\tshares\t3109519939.0000    None  None  None  None
# 3          20200630\t0\tshares\t95122430.0000    None  None  None  None
# 4         20200630\t0\tshares\t103292470.0000    None  None  None  None
# ...                                       ...     ...   ...   ...   ...
# 2351636         20200630\t4\tUSD\t493192.0000    None  None  None  None
# 2351637        20190630\t4\tUSD\t6020000.0000    None  None  None  None
# 2351638        20200630\t4\tUSD\t1000000.0000    None  None  None  None
# 2351639         20190630\t0\tUSD\t454643.0000    None  None  None  None
# 2351640         20200630\t0\tUSD\t761613.0000    None  None  None  None
#
#          coreg  value  footnote
# 0          NaN    NaN       NaN
# 1          NaN    NaN       NaN
# 2          NaN    NaN       NaN
# 3          NaN    NaN       NaN
# 4          NaN    NaN       NaN
# ...        ...    ...       ...
# 2351636    NaN    NaN       NaN
# 2351637    NaN    NaN       NaN
# 2351638    NaN    NaN       NaN
# 2351639    NaN    NaN       NaN
# 2351640    NaN    NaN       NaN
#
# [2351641 rows x 9 columns]

# %%
df = pd.read_fwf('../Data/num_2020q3.txt', header=None, names=['adsh','tag','version','ddate','qtrs', 'uom','coreg','value', 'footnote'])
df
# Out:
#                                                       adsh   tag  version  \
# 0        adsh\ttag\tversion\tcoreg\tddate\tqtrs\tuom\tv...   NaN      NaN
# 1        0001661920-20-000055\tEntityCommonStockSharesO...   NaN      NaN
# 2        0001469709-20-000039\tEntityCommonStockSharesO...   NaN      NaN
# 3        0001437557-20-000069\tEntityCommonStockSharesO...   NaN      NaN
# 4        0001628280-20-010192\tEntityCommonStockSharesO...   NaN      NaN
# ...                                                    ...   ...      ...
# 2351636  0001731122-20-000975\tSharesIssuedInKindForPre...  0000      NaN
# 2351637  0001731122-20-000975\tStockIssuedPursuantToWar...   NaN      NaN
# 2351638  0001731122-20-000975\tStockIssuedPursuantToWar...   NaN      NaN
# 2351639  0001731122-20-000975\tStockoptionsComp\t000173...   NaN      NaN
# 2351640  0001731122-20-000975\tStockoptionsComp\t000173...   NaN      NaN
#
#          ddate  qtrs  uom  coreg  value  footnote
# 0          NaN   NaN  NaN    NaN    NaN       NaN
# 1          NaN   NaN  NaN    NaN    NaN       NaN
# 2          NaN   NaN  NaN    NaN    NaN       NaN
# 3          NaN   NaN  NaN    NaN    NaN       NaN
# 4          NaN   NaN  NaN    NaN    NaN       NaN
# ...        ...   ...  ...    ...    ...       ...
# 2351636    NaN   NaN  NaN    NaN    NaN       NaN
# 2351637    NaN   NaN  NaN    NaN    NaN       NaN
# 2351638    NaN   NaN  NaN    NaN    NaN       NaN
# 2351639    NaN   NaN  NaN    NaN    NaN       NaN
# 2351640    NaN   NaN  NaN    NaN    NaN       NaN
#
# [2351641 rows x 9 columns]

# %%
df = pd.read_csv('../Data/num_2020q3.txt', sep=r'\s{2,}', engine='python')
##df = df[0].str.split(',', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-12-5eaf4455826c> in <module>
# ----> 1 df = pd.read_csv('../Data/num_2020q3.txt', sep=r'\s{2,}', engine='python')
#       2 ##df = df[0].str.split(',', expand=True)
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1184     def read(self, nrows=None):
#    1185         nrows = _validate_integer("nrows", nrows)
# -> 1186         ret = self._engine.read(nrows)
#    1187
#    1188         # May alter columns / col_dict
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\io\parsers.py in read(self, rows)
#    2571             content = content[1:]
#    2572
# -> 2573         alldata = self._rows_to_cols(content)
#    2574         data = self._exclude_implicit_index(alldata)
#    2575
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\io\parsers.py in _rows_to_cols(self, content)
#    3223                     msg += ". " + reason
#    3224
# -> 3225                 self._alert_malformed(msg, row_num + 1)
#    3226
#    3227         # see gh-13320
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\io\parsers.py in _alert_malformed(self, msg, row_num)
#    2984         """
#    2985         if self.error_bad_lines:
# -> 2986             raise ParserError(msg)
#    2987         elif self.warn_bad_lines:
#    2988             base = f"Skipping line {row_num}: "
#
# ParserError: Expected 2 fields in line 3624, saw 3. Error could possibly be due to quotes being ignored when a multi-char delimiter is used.

# %%
##q3_2020 = pd.read_csv('../Data/num_2020q3.txt', sep="\")
##q3_2020 = q3_2020 [0].str.split(',', expand=True)

# %%
df = pd.read_csv(os.path.join(maindir, '../Data/num_2020q3.txt'),\
skiprows = 2, delimiter = r'\s+', header = None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a48e3e0d887f> in <module>
# ----> 1 df = pd.read_csv(os.path.join(maindir, '../Data/num_2020q3.txt'),\
#       2 skiprows = 2, delimiter = r'\s+', header = None)
#
# NameError: name 'maindir' is not defined

# %%
df
